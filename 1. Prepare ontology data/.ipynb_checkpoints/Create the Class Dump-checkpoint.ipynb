# %%
import pandas as pd
import numpy as np
import re

# %%
f = open("Classes.nt", "w", encoding="utf-8")

# %% [markdown]
# # Retrieve the Data from LOV

# %%
lov_df = pd.read_csv("./../0. Ontologies Data/LOV/all_classes_from_lov.csv", encoding="utf-8", names=["Class","Context","Label","Description"], skiprows=1).replace(np.nan, "")
lov_df
# Out:
#                                         Class  \
# 0           http://commontag.org/ns#ReaderTag
# 1             http://commontag.org/ns#AutoTag
# 2                 http://commontag.org/ns#Tag
# 3           http://commontag.org/ns#AuthorTag
# 4       http://commontag.org/ns#TaggedContent
# ...                                       ...
# 3026     https://w3id.org/tree#PrefixRelation
# 3027  https://w3id.org/tree#SubstringRelation
# 3028  https://w3id.org/tree#InBetweenRelation
# 3029  https://w3id.org/tree#ConditionalImport
# 3030               https://w3id.org/tree#Node
#
#                               Context                Label  \
# 0     http://commontag.org/ns#context           Reader Tag
# 1     http://commontag.org/ns#context             Auto Tag
# 2     http://commontag.org/ns#context                  Tag
# 3     http://commontag.org/ns#context           Author Tag
# 4     http://commontag.org/ns#context       Tagged Content
# ...                               ...                  ...
# 3026    https://w3id.org/tree#context      Prefix Relation
# 3027    https://w3id.org/tree#context   Substring Relation
# 3028    https://w3id.org/tree#context  In Between Relation
# 3029    https://w3id.org/tree#context   Conditional Import
# 3030    https://w3id.org/tree#context                 Node
#
#                                             Description
# 0     A Tag asserted by the reader (consumer) of a c...
# 1     A Tag asserted by an automated tool on a conte...
# 2     A Common Tag associating a URI and a keyword t...
# 3     A Tag asserted by the author of a content reso...
# 4             Content which has one or more Common Tag.
# ...                                                 ...
# 3026  All members of this related node start with th...
# 3027  All members of this related node contain this ...
# 3028  For comparing intervals: all further members a...
# 3029  Import a page when the tree:path is interestin...
# 3030  A tree:Node is a node that may contain relatio...
#
# [3031 rows x 4 columns]

# %%
def write_line_LOV(line, f):
    if line["Label"] != "":
        label = re.sub("\s", " ", line["Label"])
        label = label.replace('"'," ")
        label = label.replace('\\'," ")
        f.write(f'<{line["Class"]}> <http://www.w3.org/2000/01/rdf-schema#label> "{label}".\n')
    f.write(f'<{line["Class"]}> <http://graph/origin> <{line["Context"]}>.\n')
    f.write(f'<{line["Class"]}> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/1999/02/22-rdf-syntax-ns#Class>.\n')
    if line["Description"] != "":
        description = re.sub("\s", " ",line["Description"])
        description = description.replace('"'," ")
        description = description.replace('\\'," ")
        f.write(f'<{line["Class"]}> <http://www.w3.org/2000/01/rdf-schema#description> "{description}".\n')

# %%
lov_df.apply(lambda x:write_line_LOV(x, f), axis=1)
""
# Out:
# ''

# %% [markdown]
# # Retrieve the Data from Wikidata

# %%
wk_df = pd.read_csv("./../0. Ontologies Data/Wikidata/all_classes_from_wikidata.txt", encoding="utf-8", names=["Class","Label","Description"], sep="\t").replace(np.nan, "")
wk_df
# Out:
#                                           Class                         Label  \
# 0         http://www.wikidata.org/entity/Q34627                     synagogue
# 1         http://www.wikidata.org/entity/Q62832                   observatory
# 2         http://www.wikidata.org/entity/Q11422                           toy
# 3        http://www.wikidata.org/entity/Q150784                        canyon
# 4         http://www.wikidata.org/entity/Q11461                         sound
# ...                                         ...                           ...
# 3681   http://www.wikidata.org/entity/Q64073801                 endowed chair
# 3682   http://www.wikidata.org/entity/Q65562770  fictional military operation
# 3683   http://www.wikidata.org/entity/Q54982412              songwriting team
# 3684  http://www.wikidata.org/entity/Q107655869               group of awards
# 3685   http://www.wikidata.org/entity/Q15706911              fictional object
#
#                                             Description
# 0          Jewish (or rarely Samaritan) house of prayer
# 1     location used for observing terrestrial or cel...
# 2                     object intended to be played with
# 3                   wide and deep ravine between cliffs
# 4     mechanical wave that is an oscillation of pres...
# ...                                                 ...
# 3681  professorship that is supported by a permanent...
# 3682  military operation which only exists in a work...
# 3683                    team of two or more songwriters
# 3684
# 3685         object appearing only in fictional stories
#
# [3686 rows x 3 columns]

# %%
def write_line_wikidata(line, f):
    if line["Label"] != "":
        label = re.sub("\s", " ", line["Label"])
        label = label.replace('"'," ")
        label = label.replace('\\'," ")
        f.write(f'<{line["Class"]}> <http://www.w3.org/2000/01/rdf-schema#label> "{label}".\n')
    f.write(f'<{line["Class"]}> <http://graph/origin> <http://wikidata.org>.\n')
    f.write(f'<{line["Class"]}> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/1999/02/22-rdf-syntax-ns#Class>.\n')
    if line["Description"] != "":
        description = re.sub("\s", " ", line["Description"])
        description = description.replace('"'," ")
        description = description.replace('\\'," ")
        f.write(f'<{line["Class"]}> <http://www.w3.org/2000/01/rdf-schema#description> "{description}".\n')

# %%
wk_df.apply(lambda x:write_line_wikidata(x, f), axis=1)
""
# Out:
# ''

# %%
f.close()
