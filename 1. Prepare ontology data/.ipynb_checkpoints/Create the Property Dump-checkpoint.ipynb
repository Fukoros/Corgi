# %%
import pandas as pd
import numpy as np
import re

# %%
f = open("Properties.nt", "w", encoding="utf-8")

# %% [markdown]
# # Retrieve the Data from LOV

# %%
lov_df = pd.read_csv("./../0. Ontologies Data/LOV/all_props_from_lov.csv", encoding="utf-8", names=["Property","Type","Context","Range","Label","Description", "Domain"], skiprows=1).replace(np.nan, "")
lov_df["Domain"] = lov_df["Domain"].map(lambda x: x[2:-2].split("', '"))
lov_df["Range"] = lov_df["Range"].map(lambda x: x[2:-2].split("', '"))
lov_df
# Out:
#                                                 Property  \
# 0       http://aims.fao.org/aos/geopolitical.owl#HDIUnit
# 1      http://aims.fao.org/aos/geopolitical.owl#HDITotal
# 2      http://aims.fao.org/aos/geopolitical.owl#landA...
# 3      http://aims.fao.org/aos/geopolitical.owl#nameL...
# 4      http://aims.fao.org/aos/geopolitical.owl#natio...
# ...                                                  ...
# 42653                    https://w3id.org/tree#timeQuery
# 42654               https://w3id.org/tree#remainingItems
# 42655                       https://w3id.org/tree#search
# 42656                        https://w3id.org/tree#shape
# 42657                         https://w3id.org/tree#zoom
#
#                                                     Type  \
# 0         http://www.w3.org/2002/07/owl#DatatypeProperty
# 1         http://www.w3.org/2002/07/owl#DatatypeProperty
# 2         http://www.w3.org/2002/07/owl#DatatypeProperty
# 3         http://www.w3.org/2002/07/owl#DatatypeProperty
# 4         http://www.w3.org/2002/07/owl#DatatypeProperty
# ...                                                  ...
# 42653  http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 42654  http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 42655  http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 42656  http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 42657  http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
#
#                                                 Context  \
# 0      http://aims.fao.org/aos/geopolitical.owl#context
# 1      http://aims.fao.org/aos/geopolitical.owl#context
# 2      http://aims.fao.org/aos/geopolitical.owl#context
# 3      http://aims.fao.org/aos/geopolitical.owl#context
# 4      http://aims.fao.org/aos/geopolitical.owl#context
# ...                                                 ...
# 42653                     https://w3id.org/tree#context
# 42654                     https://w3id.org/tree#context
# 42655                     https://w3id.org/tree#context
# 42656                     https://w3id.org/tree#context
# 42657                     https://w3id.org/tree#context
#
#                                                Range            Label  \
# 0          [http://www.w3.org/2001/XMLSchema#string]
# 1           [http://www.w3.org/2001/XMLSchema#float]
# 2          [http://www.w3.org/2001/XMLSchema#string]   land area unit
# 3                                                 []       nameListFR
# 4                                                 []    nationalityIT
# ...                                              ...              ...
# 42653    [http://www.w3.org/2001/XMLSchema#dateTime]       Time Query
# 42654     [http://www.w3.org/2001/XMLSchema#integer]  Remaining Items
# 42655  [http://www.w3.org/ns/hydra/core#IriTemplate]           Search
# 42656         [http://www.w3.org/ns/shacl#NodeShape]            Shape
# 42657       [http://www.w3.org/2001/XMLSchema#float]       Zoom level
#
#                                              Description  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 42653  Will search for elements starting from a certa...
# 42654  Total number of items of this node and its chi...
# 42655          The Node can be searched for child nodes.
# 42656  The SHACL shape the members of the collection ...
# 42657     The zoom level of the tile cfr. OSM convention
#
#                                    Domain
# 0                                      []
# 1                                      []
# 2                                      []
# 3                                      []
# 4                                      []
# ...                                   ...
# 42653        [https://w3id.org/tree#Node]
# 42654        [https://w3id.org/tree#Node]
# 42655        [https://w3id.org/tree#Node]
# 42656  [https://w3id.org/tree#Collection]
# 42657        [https://w3id.org/tree#Node]
#
# [42658 rows x 7 columns]

# %%
def write_line_LOV(line, f):
    if line["Label"] != "":
        label = re.sub("\s", " ", line["Label"])
        label = label.replace('"'," ")
        label = label.replace('\\'," ")
        f.write(f'<{line["Property"]}> <http://www.w3.org/2000/01/rdf-schema#label> "{label}".\n')
    f.write(f'<{line["Property"]}> <http://graph/origin> <{line["Context"]}>.\n')
    f.write(f'<{line["Property"]}> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <{line["Type"]}>.\n')
    f.write(f'<{line["Property"]}> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>.\n')
    if line["Description"] != "":
        description = re.sub("\s", " ", line["Description"])
        description = description.replace('"'," ")
        description = description.replace('\\'," ")
        f.write(f'<{line["Property"]}> <http://www.w3.org/2000/01/rdf-schema#description> "{description}".\n')
    if line["Domain"]!=['']:
        for d in line["Domain"]:
            if d[:4] == "http":
                f.write(f'<{line["Property"]}> <http://www.w3.org/2000/01/rdf-schema#domain> <{str(d)}>.\n')
    if line["Range"]!=['']:
        for r in line["Range"]:
            if r[:4] == "http":
                f.write(f'<{line["Property"]}> <http://www.w3.org/2000/01/rdf-schema#range> <{str(r)}>.\n')

# %%
lov_df.apply(lambda x:write_line_LOV(x, f), axis=1)
""
# Out:
# ''

# %% [markdown]
# # Retrieve the Data from Wikidata

# %%
wk_df = pd.read_csv("./../0. Ontologies Data/Wikidata/all_props_from_wikidata.txt", encoding="utf-8", names=["Property","Label","Description","Wikibase domain","Range", "Domain"], sep="\t").replace(np.nan, "")
wk_df
# Out:
#                                                 Property  \
# 0                        http://www.wikidata.org/prop/P6
# 1                 http://www.wikidata.org/prop/direct/P6
# 2      http://www.wikidata.org/prop/direct-normalized/P6
# 3              http://www.wikidata.org/prop/statement/P6
# 4        http://www.wikidata.org/prop/statement/value/P6
# ...                                                  ...
# 60169         http://www.wikidata.org/prop/direct/P10850
# 60170  http://www.wikidata.org/prop/direct-normalized...
# 60171      http://www.wikidata.org/prop/statement/P10850
# 60172  http://www.wikidata.org/prop/statement/value/P...
# 60173  http://www.wikidata.org/prop/statement/value-n...
#
#                        Label  \
# 0         head of government
# 1         head of government
# 2         head of government
# 3         head of government
# 4         head of government
# ...                      ...
# 60169  Kultboy video game ID
# 60170  Kultboy video game ID
# 60171  Kultboy video game ID
# 60172  Kultboy video game ID
# 60173  Kultboy video game ID
#
#                                              Description  \
# 0      head of the executive power of this town, city...
# 1      head of the executive power of this town, city...
# 2      head of the executive power of this town, city...
# 3      head of the executive power of this town, city...
# 4      head of the executive power of this town, city...
# ...                                                  ...
# 60169  identifier of a video game in the Kultboy data...
# 60170  identifier of a video game in the Kultboy data...
# 60171  identifier of a video game in the Kultboy data...
# 60172  identifier of a video game in the Kultboy data...
# 60173  identifier of a video game in the Kultboy data...
#
#                               Wikibase domain  \
# 0      http://wikiba.se/ontology#WikibaseItem
# 1      http://wikiba.se/ontology#WikibaseItem
# 2      http://wikiba.se/ontology#WikibaseItem
# 3      http://wikiba.se/ontology#WikibaseItem
# 4      http://wikiba.se/ontology#WikibaseItem
# ...                                       ...
# 60169    http://wikiba.se/ontology#ExternalId
# 60170    http://wikiba.se/ontology#ExternalId
# 60171    http://wikiba.se/ontology#ExternalId
# 60172    http://wikiba.se/ontology#ExternalId
# 60173    http://wikiba.se/ontology#ExternalId
#
#                                                    Range  \
# 0      http://www.wikidata.org/entity/Q95074,http://w...
# 1      http://www.wikidata.org/entity/Q95074,http://w...
# 2      http://www.wikidata.org/entity/Q95074,http://w...
# 3      http://www.wikidata.org/entity/Q95074,http://w...
# 4      http://www.wikidata.org/entity/Q95074,http://w...
# ...                                                  ...
# 60169
# 60170
# 60171
# 60172
# 60173
#
#                                                   Domain
# 0      http://www.wikidata.org/entity/Q327333,http://...
# 1      http://www.wikidata.org/entity/Q327333,http://...
# 2      http://www.wikidata.org/entity/Q327333,http://...
# 3      http://www.wikidata.org/entity/Q327333,http://...
# 4      http://www.wikidata.org/entity/Q327333,http://...
# ...                                                  ...
# 60169               http://www.wikidata.org/entity/Q7889
# 60170               http://www.wikidata.org/entity/Q7889
# 60171               http://www.wikidata.org/entity/Q7889
# 60172               http://www.wikidata.org/entity/Q7889
# 60173               http://www.wikidata.org/entity/Q7889
#
# [60174 rows x 6 columns]

# %%
def write_line_wikidata(line, f):
    if line["Label"] != "":
        label = re.sub("\s", " ", line["Label"])
        label = label.replace('"'," ")
        label = label.replace('\\'," ")
        f.write(f'<{line["Property"]}> <http://www.w3.org/2000/01/rdf-schema#label> "{label}".\n')
    f.write(f'<{line["Property"]}> <http://graph/origin> <http://wikidata.org>.\n')
    f.write(f'<{line["Property"]}> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2000/01/rdf-schema#Property>.\n')
    if line["Description"] != "":
        description = re.sub("\s", " ", line["Description"])
        description = description.replace('"'," ")
        description = description.replace('\\'," ")
        f.write(f'<{line["Property"]}> <http://www.w3.org/2000/01/rdf-schema#description> "{description}".\n')
    if line["Domain"] != " ":
        for d in line["Domain"].lower().split(","):
            if d[:4] == "http":
                f.write(f'<{line["Property"]}> <http://www.w3.org/2000/01/rdf-schema#domain> <{d}>.\n')
    if line["Range"] != " ":
        for r in line["Range"].lower().split(","):
            if r[:4] == "http":
                f.write(f'<{line["Property"]}> <http://www.w3.org/2000/01/rdf-schema#range> <{r}>.\n')

# %%
wk_df.apply(lambda x:write_line_wikidata(x, f), axis=1)
""
# Out:
# ''

# %%
f.close()
