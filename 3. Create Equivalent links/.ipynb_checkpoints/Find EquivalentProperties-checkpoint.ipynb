# %%
from SPARQLWrapper import SPARQLWrapper, BASIC
import time

# %% [markdown]
# # Retrieve the server info

# %%
import json
  
# Opening JSON file
f = open('./../../config.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)
  
url_server = data["ServerInfo"]["url"]
    
f.close()

# %% [markdown]
# # Retrieve the name of the ontologies

# %%
# %%time
sparql = SPARQLWrapper(url_server)
sparql.setReturnFormat('json')
sparql.method = 'GET'

ontos = set()

q = """SELECT DISTINCT ?ontology
WHERE {
    [] <http://graph/origin>  ?ontology.
}"""

sparql.setQuery(q)
response = sparql.queryAndConvert()
for r in response["results"]["bindings"]:
    
    ontos.add(r["ontology"]["value"])
# Out:
# Wall time: 6.67 s

# %% [markdown]
# # Find the links between each possible tuple of ontologies

# %%
# %%time

global_threshold = 0.5
relative_threshold = 0.02

res_prop_linked_to = {}

list_ontos = list(ontos)

for onto_1 in list_ontos:
    for onto_2 in list_ontos:
        if onto_1 != onto_2:
            print(f"Working on {onto_1} AND {onto_2}")
            start = time.time()

            q = """
                SELECT ?a ?b
                WHERE {
                        { << ?a <http://graph/simComputed> ?b >> <http://graph/sim> ?sim_value. }
                    UNION
                        { << ?b <http://graph/simComputed> ?a >> <http://graph/sim> ?sim_value. }
                    FILTER (?sim_value > ?max_sim_value-"""+str(relative_threshold)+""")
                    FILTER (?sim_value >"""+str(global_threshold)+""")
                    # ?b <http://graph/origin> '"""+onto_2+"""'.

                    {
                        SELECT ?a (MAX (?sim_value) AS ?max_sim_value)
                        WHERE {
                                {<< ?a <http://graph/simComputed> ?b >> <http://graph/sim> ?sim_value}
                            UNION 
                                {<< ?b <http://graph/simComputed> ?a >> <http://graph/sim> ?sim_value}
                            # ?a <http://graph/origin> '"""+onto_1+"""'.
                            # ?b <http://graph/origin> '"""+onto_2+"""'.
                        } GROUP BY ?a 
                    }
                } ORDER BY DESC(?sim_value)
            """

            sparql.setQuery(q)
            response = sparql.queryAndConvert()
            for r in response["results"]["bindings"]:
                if r["a"]["value"] in res_prop_linked_to:
                    res_prop_linked_to[r["a"]["value"]].add(r["b"]["value"])
                else:
                    res_prop_linked_to[r["a"]["value"]] = {r["b"]["value"]}

            end = time.time()
            print(end - start)
# Out:
# Working on rdf AND owl
# 6.121473550796509
# Working on rdf AND schema
# 6.163607835769653
# Working on rdf AND w3
# 6.134899616241455
# Working on rdf AND wikidata
# 6.209463834762573
# Working on rdf AND purl
# 6.11240029335022
# Working on rdf AND foaf
# 6.156975746154785
# Working on rdf AND wikibase
# 6.13064432144165
# Working on rdf AND dbpedia
# 6.160075426101685
# Working on owl AND rdf
# 6.128941059112549
# Working on owl AND schema
# 6.791743278503418
# Working on owl AND w3
# 6.1506547927856445
# Working on owl AND wikidata
# 7.890986680984497
# Working on owl AND purl
# 6.087620258331299
# Working on owl AND foaf
# 6.1294636726379395
# Working on owl AND wikibase
# 6.109450817108154
# Working on owl AND dbpedia
# 6.791297197341919
# Working on schema AND rdf
# 6.194568395614624
# Working on schema AND owl
# 6.866917848587036
# Working on schema AND w3
# 6.284934759140015
# Working on schema AND wikidata
# 77.05761241912842
# Working on schema AND purl
# 6.1358819007873535
# Working on schema AND foaf
# 6.771126985549927
# Working on schema AND wikibase
# 6.102450370788574
# Working on schema AND dbpedia
# 22.6995906829834
# Working on w3 AND rdf
# 6.1225457191467285
# Working on w3 AND owl
# 6.130634784698486
# Working on w3 AND schema
# 6.181553602218628
# Working on w3 AND wikidata
# 6.175584554672241
# Working on w3 AND purl
# 6.1186487674713135
# Working on w3 AND foaf
# 6.134788513183594
# Working on w3 AND wikibase
# 6.110432147979736
# Working on w3 AND dbpedia
# 6.208873748779297
# Working on wikidata AND rdf
# 6.265078067779541
# Working on wikidata AND owl
# 9.164271831512451
# Working on wikidata AND schema
# 68.74675798416138
# Working on wikidata AND w3
# 6.350975751876831
# Working on wikidata AND purl
# 6.129139184951782
# Working on wikidata AND foaf
# 8.320313930511475
# Working on wikidata AND wikibase
# 6.117480039596558
# Working on wikidata AND dbpedia
# 63.09955811500549
# Working on purl AND rdf
# 6.170418739318848
# Working on purl AND owl
# 6.111428737640381
# Working on purl AND schema
# 6.09113335609436
# Working on purl AND w3
# 6.103943347930908
# Working on purl AND wikidata
# 6.114500045776367
# Working on purl AND foaf
# 6.097370624542236
# Working on purl AND wikibase
# 6.095954895019531
# Working on purl AND dbpedia
# 6.100887060165405
# Working on foaf AND rdf
# 6.133914947509766
# Working on foaf AND owl
# 6.15595555305481
# Working on foaf AND schema
# 6.58405613899231
# Working on foaf AND w3
# 6.128957509994507
# Working on foaf AND wikidata
# 7.093683958053589
# Working on foaf AND purl
# 6.099952220916748
# Working on foaf AND wikibase
# 6.100641965866089
# Working on foaf AND dbpedia
# 6.5996057987213135
# Working on wikibase AND rdf
# 6.110867261886597
# Working on wikibase AND owl
# 6.139033555984497
# Working on wikibase AND schema
# 6.1109559535980225
# Working on wikibase AND w3
# 6.1522603034973145
# Working on wikibase AND wikidata
# 6.135990858078003
# Working on wikibase AND purl
# 6.131958961486816
# Working on wikibase AND foaf
# 6.126955986022949
# Working on wikibase AND dbpedia
# 6.105679988861084
# Working on dbpedia AND rdf
# 6.222862243652344
# Working on dbpedia AND owl
# 6.9190993309021
# Working on dbpedia AND schema
# 20.063701391220093
# Working on dbpedia AND w3
# 6.2046918869018555
# Working on dbpedia AND wikidata
# 64.16041541099548
# Working on dbpedia AND purl
# 6.104771852493286
# Working on dbpedia AND foaf
# 6.7012927532196045
# Working on dbpedia AND wikibase
# 6.112615346908569
# Wall time: 12min 14s

# %%
len(res_prop_linked_to)
# Out:
# 14318

# %%
f = open("equivalence.ttl", "w", encoding="utf-8")

for prop_a in res_prop_linked_to:
    for prop_b in res_prop_linked_to[prop_a]:
        if (prop_b in res_prop_linked_to) and (prop_a in res_prop_linked_to[prop_b]):
            f.write(f"<{prop_a}> <http://www.w3.org/2002/07/owl#equivalentProperty> <{prop_b}> .\n")
    
f.close()
